# %% [markdown]
# <a href="https://colab.research.google.com/github/DAJananiTK/Python-Learning-Casestudies/blob/main/conditional_statements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##  **5. Case Study: Bank Loan Eligibility System**
# **Instructions:**
#
# 1. Create variables:
#    customer_name, age, income, credit_score, existing_loan
#
# 2. Use conditional statements (if, elif, else) to:
#
#    • Approve loan if age ≥ 21, income ≥ 30000, credit_score ≥ 700, and no existing loan
#
#    • Conditionally approve loan if credit_score ≥ 600 and income ≥ 40000
#    • Otherwise reject the loan application
#
# 3. Display customer details and loan status using print()
#
# ---

# %%
#creating variables
customer_name="radha"
age=30
income=40000
credit_score=650
existing_loan=False

#using conditional statements
if age >=21 and income >=30000:
  if credit_score>=700 and existing_loan == False:
    status=" Loan Approved"
  elif credit_score>=600 and income>=40000:
    status="Conditionally Approved"
  else:
    status="Not Eligible for loan"
else:
  status="Loan Application Rejected"


#display customer details and status of loan
print(f"Customer Name: {customer_name}")
print(f"Age: {age}")
print(f"Income: {income}")
print(f"Credit Score: {credit_score}")
print(f"Existing Loan: {existing_loan}")
print(f"Loan Status: {status}")
# Out:
# Customer Name: radha
# Age: 30
# Income: 40000
# Credit Score: 650
# Existing Loan: False
# Loan Status: Conditionally Approved

# %% [markdown]
# ## **Case Study Scholarship Eligibility Checker**
#
# **Instructions:**
#
# 1. Create variables: `student_name`, `marks`, `attendance`, `family_income`.
# 2. Use conditional statements (`if`, `elif`, `else`) to:
#
#    * Award **Full Scholarship** if marks ≥ 90 and attendance ≥ 90.
#    * Award **Half Scholarship** if marks ≥ 80 or attendance ≥ 85.
#    * Award **Need-Based Scholarship** if marks ≥ 70 and `family_income` < 30000.
#    * Otherwise, display **Not Eligible**.
# 3. Display all data (no loops).

# %%
#creating variables
student_name="samyuktha"
marks=60
attendance=85
family_income=35000

#using conditional statements
if marks>=90 and attendance>=90:
  scholarship="Full Scholarship"
elif marks >=80 or attendance>=85:
  scholarship="Half Scholarship"
elif marks>=70 and family_income<30000:
  scholarship= "Need-Based Scholarship"
else:
  scholarship="Not Eligible"


#display student details and scholarship
print(f"Student Name: {student_name}")
print(f"Marks: {marks}")
print(f"Attendance: {attendance}")
print(f"Family Income: {family_income}")
print(f"Scholarship: {scholarship}")
# Out:
# Student Name: samyuktha
# Marks: 60
# Attendance: 85
# Family Income: 35000
# Scholarship: Half Scholarship
