# %% [markdown]
# <a href="https://colab.research.google.com/github/DAJananiTK/Python-Learning-Casestudies/blob/main/User_Defined_Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Case Study – Arithmetic Calculator using User Defined Function**
#
# **Instructions**
#
# Create a function called arth_cal()
#
# Pass two parameters to the function
#
# Inside the function:Perform  addition, subtraction, multiplication
#
# Return all three values using multiple return statements
#
#
# Take two numbers from the user using input()
#
# Store returned values in separate variables
#
# Display:Sum, Difference, Multiplication

# %%
1#Create a function called arth_cal() UDF
def arth_cal(a,b):

  s= a+b
  d= a-b
  m= a*b
  return s,d,m # Multiple return values


# Take input from user
a=int(input("enter the first number: "))
b=int(input("enter the second number: "))

# Store returned values in separate variables
#function call
sum_result, diff_result, mul_result = arth_cal(a, b)

# Display results
print("Sum =", sum_result)
print("Difference =", diff_result)
print("Multiplication =", mul_result)
# Out:
# enter the first number: 10
# enter the second number: 10
# Sum = 20
# Difference = 0
# Multiplication = 100

# %% [markdown]
# # **Case Study – Student Marks Analysis using Function and Loop**
#
# **Instructions**
#
# Create a list called marks
#
# Create a function called marks_analysis() and pass the marks list to the function
#
# Inside the function:
#
# Use a for loop to display all marks
#
# Find total marks
#
# Find average marks
#
#
# Return total and average marks, call the function, and display: Student Marks, Total Marks,  Average Marks

# %%
#Create a list called marks
marks=[45,56,65,73,85,92]
def marks_analysis(marks):
    print("Student Marks :")
    for i in marks:
      print(i)

# Operations
    total = sum(marks)
    average = total / len(marks)
    return total, average
# Function Call
total_marks, average_marks = marks_analysis(marks)
# Output
print("\nTotal Marks   :", total_marks)
print("Average Marks :", average_marks)
# Out:
# Student Marks :
# 45
# 56
# 65
# 73
# 85
# 92
#
# Total Marks   : 416
# Average Marks : 69.33333333333333
