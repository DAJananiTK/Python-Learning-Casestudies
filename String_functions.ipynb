# %% [markdown]
# <a href="https://colab.research.google.com/github/DAJananiTK/Python-Learning-Casestudies/blob/main/String_functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# """
# ## **Case Study – Email Username Generator**
#
# **Instructions:**
#
# • Create variables: full_name, domain_name
#
# • Take input from the user using input() function
#
# • Convert full_name into lowercase using lower()
#
# • Remove spaces in name and replace with dot using replace()
#
# • Split full_name using split() function
#
# • Join name parts using join() function if needed
#
# • Create email in format: name@domain
#
# • Display only Full Name and Generated Email
#
# • Use print() and f-string for output display
#
# """

# %%
# Email Generator

# Taking input from user
full_name = input("Enter Full Name: ").lower().replace(" ",".")
domain_name = input("Enter Domain Name: ")
split_name=full_name.split()
joined_name=(".").join(split_name)
email=joined_name+"@"+domain_name

print("\n  ------ display the student details -------")
print(f"Full Name: {full_name.title()}")
print(f"Generated Email: {email}")
# Out:
# Enter Full Name: janani tamilselvan
# Enter Domain Name: gmail.com
#
#   ------ display the student details -------
# Full Name: Janani.Tamilselvan
# Generated Email: janani.tamilselvan@gmail.com
